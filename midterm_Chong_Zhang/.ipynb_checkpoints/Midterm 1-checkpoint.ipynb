# %%
import numpy as np
import pandas as pd
import scipy as sp
from sklearn.cluster import KMeans
import scipy.spatial.distance as dist
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.neighbors import kneighbors_graph
from scipy.spatial import distance_matrix
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from plotly import express as px

# %%
# problem 1.1

data = np.array([[2,2],
                [-1,1],
                [3,1],
                [0,-1],
                [-2,-2]])

centroids = np.array([[-3,-1],
                     [2,1]])

dist_matrix = np.zeros((5,2))

def k_mean_euclidean(data,centroids,dist_matrix):
    for i in range(data.shape[0]):
        for j in range(centroids.shape[0]):
            distance = dist.euclidean(data[i],centroids[j])# euclidean distance
            dist_matrix[i,j] = distance
    cluster = np.asarray([np.argmin(i) for i in dist_matrix])
    new_data = pd.DataFrame(data)
    new_data["cluster"] = cluster
    centroids = new_data.groupby(['cluster']).mean().to_numpy() # calculate the new center for each centroid

    
    return centroids,cluster,dist_matrix

centroids,cluster,dist_matrix = k_mean_euclidean(data,centroids,dist_matrix)

print ("Iteration 1:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")


centroids,cluster,dist_matrix = k_mean_euclidean(data,centroids,dist_matrix)

print ("Iteration 2:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")

centroids,cluster,dist_matrix = k_mean_euclidean(data,centroids,dist_matrix)

print ("Iteration 3:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")

centroids,cluster,dist_matrix = k_mean_euclidean(data,centroids,dist_matrix)

print ("Iteration 4:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")
# Out:
# Iteration 1:
# #################
# centroids:
#  [[-1.5        -0.5       ]
#  [ 1.66666667  0.66666667]]
# #################
# cluster:
#  [1 0 1 1 0]
# #################
# distance matrix:
# [[5.83095189 1.        ]
#  [2.82842712 3.        ]
#  [6.32455532 1.        ]
#  [3.         2.82842712]
#  [1.41421356 5.        ]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# Iteration 2:
# #################
# centroids:
#  [[-1.         -0.66666667]
#  [ 2.5         1.5       ]]
# #################
# cluster:
#  [1 0 1 0 0]
# #################
# distance matrix:
# [[4.30116263 1.37436854]
#  [1.58113883 2.68741925]
#  [4.74341649 1.37436854]
#  [1.58113883 2.3570226 ]
#  [1.58113883 4.5338235 ]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# Iteration 3:
# #################
# centroids:
#  [[-1.         -0.66666667]
#  [ 2.5         1.5       ]]
# #################
# cluster:
#  [1 0 1 0 0]
# #################
# distance matrix:
# [[4.01386486 0.70710678]
#  [1.66666667 3.53553391]
#  [4.33333333 0.70710678]
#  [1.05409255 3.53553391]
#  [1.66666667 5.70087713]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# Iteration 4:
# #################
# centroids:
#  [[-1.         -0.66666667]
#  [ 2.5         1.5       ]]
# #################
# cluster:
#  [1 0 1 0 0]
# #################
# distance matrix:
# [[4.01386486 0.70710678]
#  [1.66666667 3.53553391]
#  [4.33333333 0.70710678]
#  [1.05409255 3.53553391]
#  [1.66666667 5.70087713]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
# problem 1.2

data = np.array([[2,2],
                [-1,1],
                [3,1],
                [0,-1],
                [-2,-2]])

centroids = np.array([[-3,-1],
                     [2,1]])

dist_matrix = np.zeros((5,2))
def k_mean_Manhatten(data,centroids,dist_matrix):
    for i in range(data.shape[0]):
        for j in range(centroids.shape[0]):
            distance = dist.cityblock(data[i],centroids[j])# Manhatten distance
            dist_matrix[i,j] = distance
    cluster = np.asarray([np.argmin(i) for i in dist_matrix])
    new_data = pd.DataFrame(data)
    new_data["cluster"] = cluster
    centroids = new_data.groupby(['cluster']).mean().to_numpy() # calculate the new center for each centroid
    
    return centroids,cluster,dist_matrix

centroids,cluster,dist_matrix = k_mean_Manhatten(data,centroids,dist_matrix)

print ("Iteration 1:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")


centroids,cluster,dist_matrix = k_mean_Manhatten(data,centroids,dist_matrix)

print ("Iteration 2:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")

centroids,cluster,dist_matrix = k_mean_Manhatten(data,centroids,dist_matrix)

print ("Iteration 3:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")

centroids,cluster,dist_matrix = k_mean_Manhatten(data,centroids,dist_matrix)

print ("Iteration 4:")
print ("#################")
print ("centroids:\n", centroids) # centroids coordinates
print ("#################")
print ("cluster:\n", cluster) # cluster assignment
print ("#################")
print ("distance matrix:")
print (dist_matrix)
print ("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")
# Out:
# Iteration 1:
# #################
# centroids:
#  [[-1.         -1.5       ]
#  [ 1.33333333  1.33333333]]
# #################
# cluster:
#  [1 1 1 0 0]
# #################
# distance matrix:
# [[8. 1.]
#  [4. 3.]
#  [8. 1.]
#  [3. 4.]
#  [2. 7.]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# Iteration 2:
# #################
# centroids:
#  [[-1.         -0.66666667]
#  [ 2.5         1.5       ]]
# #################
# cluster:
#  [1 0 1 0 0]
# #################
# distance matrix:
# [[6.5        1.33333333]
#  [2.5        2.66666667]
#  [6.5        2.        ]
#  [1.5        3.66666667]
#  [1.5        6.66666667]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# Iteration 3:
# #################
# centroids:
#  [[-1.         -0.66666667]
#  [ 2.5         1.5       ]]
# #################
# cluster:
#  [1 0 1 0 0]
# #################
# distance matrix:
# [[5.66666667 1.        ]
#  [1.66666667 4.        ]
#  [5.66666667 1.        ]
#  [1.33333333 5.        ]
#  [2.33333333 8.        ]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# Iteration 4:
# #################
# centroids:
#  [[-1.         -0.66666667]
#  [ 2.5         1.5       ]]
# #################
# cluster:
#  [1 0 1 0 0]
# #################
# distance matrix:
# [[5.66666667 1.        ]
#  [1.66666667 4.        ]
#  [5.66666667 1.        ]
#  [1.33333333 5.        ]
#  [2.33333333 8.        ]]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
# problem 2

from sklearn.cluster import KMeans
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.neighbors import kneighbors_graph
import matplotlib.pyplot as plt 

data = np.array([[-1,2],
                [-1,1],
                [-1,0],
                [-1,-1],
                [-1,-2],
                [0,0],
                 [1,0],
                 [2,0]])

data = pd.DataFrame(data)
data = data.rename(columns = {0:"x",1:"y"})

#calculate the distance to its two nearest neighbors, obtain a distance matrix
z = np.around(kneighbors_graph(data,n_neighbors=2,mode='distance').toarray(),2)

# make the distance matrix undirected.
for i in range(z.shape[0]):
    for j in range(z.shape[0]):
        if z[i,j] !=0 and z[j,i]==0:
            z[j,i]=z[i,j]


# get the adjancency matrix based on euclidean distance and two nearest neighbors
A = np.exp(-z)
A= np.where(A==1,0, A)

# get degree matrix
D = np.diag(A.sum(axis=0))

# get laplacian matrix
L = D-A
L_pd = pd.DataFrame(L)
print ("Laplacian matrix:")
display(L_pd)

# find the eigenvalues and eigenvectors
vals, vecs = np.linalg.eig(L)

# sort
vecs = vecs[:,np.argsort(vals)]
vals = vals[np.argsort(vals)]

kmeans = KMeans(n_clusters=2)
kmeans.fit(vecs[:,0:2])
colors = kmeans.labels_
data['color'] = colors
sns.lmplot(x='x',y='y',hue="color", data=data,fit_reg=False)
plt.show()
# Out:
# Laplacian matrix:
#           0         1         2         3         4         5         6  \
# 0  0.503215 -0.367879 -0.135335  0.000000  0.000000  0.000000  0.000000
# 1 -0.367879  0.735759 -0.367879  0.000000  0.000000  0.000000  0.000000
# 2 -0.135335 -0.367879  1.374309 -0.367879 -0.135335 -0.367879  0.000000
# 3  0.000000  0.000000 -0.367879  0.735759 -0.367879  0.000000  0.000000
# 4  0.000000  0.000000 -0.135335 -0.367879  0.503215  0.000000  0.000000
# 5  0.000000  0.000000 -0.367879  0.000000  0.000000  0.871094 -0.367879
# 6  0.000000  0.000000  0.000000  0.000000  0.000000 -0.367879  0.735759
# 7  0.000000  0.000000  0.000000  0.000000  0.000000 -0.135335 -0.367879
#
#           7
# 0  0.000000
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  0.000000
# 5 -0.135335
# 6 -0.367879
# 7  0.503215

# %%
# problem 3

data = np.array([[4,-2,4],
                [5,-3,5],
                [2,0,2],
                [3,-1,3]])

sns.regplot(data[:,0], data[:,1])
plt.show()
from sklearn import datasets
#data = datasets.load_iris()['data']
data = data - data.mean(axis=0)

cov = np.cov(data, rowvar=False)

vals, vecs = np.linalg.eig(cov)

# sort them from high to low
vals = vals[np.argsort(-vals)]
vecs = vecs[:,np.argsort(-vals)]

print ("first principle direction: ", vecs[:,0]) # first principle direction
print ("variance for the first principle direction  == largest eigenvalue:", vals[0])  # variance for the first principle direction  == largest eigenvalue,
# Out:
# first principle direction:  [ 0.57735027 -0.57735027  0.57735027]
# variance for the first principle direction  == largest eigenvalue: 5.0

# %%
# problem 4

import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import rescale, resize, downscale_local_mean
import os

os.chdir("yaleface/")
# define a functio to vectorize the image data
def vectorize(image_name):
    image = plt.imread(image_name)
    image = rescale(image,  1/4, anti_aliasing=False, multichannel=False)
    image_vectorized = image.flatten("C")
    return image_vectorized

def eigenface(subject_name):
    # get the eigenface for subject
    sub14 = [os.listdir()[i] for i in range(len(os.listdir())) if os.listdir()[i].startswith(subject_name)]

    for i in range(len(sub14)):
        if i ==0:
            n = vectorize(sub14[i])# get the first vectorized image data
        else:
            n = np.column_stack((n,vectorize(sub14[i]))) # add the rest of the image data

    new = n.T.dot(n) # compute the X^TX matrix

    # get the eigenvalues and eigenvectors
    vals, vecs =  np.linalg.eig(new)

    # sort them from high to low
    vals = vals[np.argsort(-vals)]
    vecs = vecs[:,np.argsort(-vals)]

    print ("The top 6 eigenfaces of",subject_name)
    for i in range(6):
        face = n.dot(vecs[:,i]) # compute the eigenface
        face_reshape = np.reshape(face, (61,80)) # reshape the data to its original form
        plt.subplot(2,3,i+1)
        plt.title('Eigenface_'+str(i))
        plt.imshow(face_reshape)
        plt.axis('off')
    face_1 = n.dot(vecs[:,0])
    return face_1
face_01 = eigenface("subject01")
# Out:
# The top 6 eigenfaces of subject01

# %%
face_14 = eigenface("subject14")
# Out:
# The top 6 eigenfaces of subject14

# %%
os.chdir("../")
os.getcwd()

sub01_test = vectorize("subject01-test.gif")
sub14_test = vectorize("subject14-test.gif")

print (face_01.T.dot(sub01_test))
print (face_14.T.dot(sub01_test))
print (face_01.T.dot(sub14_test))
print (face_14.T.dot(sub14_test))
# Out:
# -9452.063358813999
# -8456.749554081878
# -8938.226834315006
# -9959.0499290608

# %%
# problem 5


import numpy as np
import networkx as nx
from sklearn.neighbors import kneighbors_graph
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


def Matrix_D(W):
    # Generate Graph and Obtain Matrix D, \\
    # from weight matrix W defining the weight on the edge between each pair of nodes.
    # Note that you can assign sufficiently large weights to non-existing edges.

    n = np.shape(W)[0]
    Graph = nx.DiGraph()
    for i in range(n):
        for j in range(n):
            Graph.add_weighted_edges_from([(i,j,min(W[i,j], W[j,i]))])
    
    res = dict(nx.all_pairs_dijkstra_path_length(Graph))
    D = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            D[i,j] = res[i][j]
    np.savetxt('D.csv', D)
    return D

# %%
data = pd.read_csv("isomap.csv",header=None) # read in the file

# get the pair wise distance matrix of 100 closest points
W = kneighbors_graph(data.T,n_neighbors=100,mode="distance").toarray() 

# adjacency matrix
A = kneighbors_graph(data.T,n_neighbors=100,include_self=False).toarray() 

plt.figure(figsize=(15,10))
sns.heatmap(A)# visulize the adjancency matrix as a heatmap
plt.show()

W[W==0]=8200 # assign the non-existing edge a relative large number
D = Matrix_D(W) # calculating pairwise shortest distance matrix

m = data.shape[1] # number of images
I = np.identity(m) # the m by m identity matrix 
one_vector = np.ones((m,m)) # m by m one matrix
H = I - (1/m)*one_vector # get the centering matrix
C = (-1/(2*m))*((H.dot(np.square(D))).dot(H)) #distance matrix C

# %%
vals, vecs = np.linalg.eig(C)


# sort them from high to low
vecs = vecs[:,np.argsort(-vals)]
vals = vals[np.argsort(-vals)]

# get two leading eigen vectors and eigenvalues
leading_vecs = vecs[:,0:2].real
leading_vals = vals[0:2].real

# construct the scaling matrix with eigenvalues
scaling_matrix = np.zeros((2,2))

for i in range(2):
    for j in range(2):
        if i == j:
            scaling_matrix[i,j] = np.sqrt(leading_vals[i])
            
# get the first two components of ISOMAP
Z_t = leading_vecs.dot(scaling_matrix)
Z_t = pd.DataFrame(Z_t)
Z_t = Z_t.rename(columns= {0:'x',1:"y"})
Z_t["image_no"] = np.array([i for i in range(data.shape[1])])


plt.figure(figsize=(15,10))
p1 = sns.regplot(data=Z_t, x="x",y="y",fit_reg=False)
image_list= [691,140,154, 406,631,278]

# annotate data points
#p1.text(Z_t["x"][image_list[0]],Z_t["y"][image_list[0]],Z_t["image_no"][image_list[0]],size='medium', color='black', weight='semibold')
#p1.text(Z_t["x"][image_list[1]],Z_t["y"][image_list[1]],Z_t["image_no"][image_list[1]],size='medium', color='black', weight='semibold')
#p1.text(Z_t["x"][image_list[2]],Z_t["y"][image_list[2]],Z_t["image_no"][image_list[2]],size='medium', color='black', weight='semibold')


for i in image_list:
    p1.text(Z_t["x"][i],Z_t["y"][i],Z_t["image_no"][i],size='medium', color='black', weight='semibold')

plt.show()
plt.figure(figsize=(15,10))
for i in image_list:
        face_reshape = np.reshape(np.asarray(data.iloc[:,i]), (64,64)).T # reshape the data to its original form
        plt.subplot(2,len(image_list)/2,image_list.index(i)+1)
        plt.title('Eigenface_'+str(i))
        plt.imshow(face_reshape)
        plt.axis('off')
# Out:
# [ 1.81996438e+02  1.49888035e+02  9.53453890e+01  4.85054188e+01
#  -3.38452120e+01  2.64926093e+01 -2.52203979e+01  1.40829969e+01
#   1.29292279e+01 -1.08848373e+01 -1.08180272e+01  9.86663668e+00
#  -9.52524803e+00 -8.18078416e+00  8.42339208e+00  8.33012349e+00
#   7.75736889e+00 -7.07726299e+00  6.91503147e+00 -6.78763539e+00
#   6.26650431e+00  5.58581436e+00 -5.66204182e+00 -5.52880765e+00
#  -5.23969220e+00  5.05628277e+00 -5.04722459e+00  4.81020677e+00
#  -4.76878810e+00  4.71869489e+00  4.55052119e+00 -4.40942417e+00
#   4.39608212e+00 -4.18233081e+00 -4.06542823e+00  4.12004891e+00
#  -7.59895215e-01 -7.67977891e-01 -7.75676230e-01 -7.88688226e-01
#  -7.94734795e-01 -7.99778964e-01 -8.11328297e-01 -8.14021665e-01
#  -8.23782784e-01 -8.34794360e-01 -8.44086381e-01 -8.52143173e-01
#  -8.57221227e-01 -8.69132917e-01 -8.73521688e-01 -8.86893013e-01
#  -8.92782262e-01 -9.07086278e-01 -9.12515047e-01 -9.31898774e-01
#  -9.40300035e-01 -9.46789063e-01 -9.53465717e-01 -9.60859982e-01
#  -9.73014735e-01 -9.81474203e-01 -9.83861935e-01 -1.01414361e+00
#  -1.01720148e+00 -1.02404580e+00 -1.03703163e+00 -1.04855869e+00
#  -1.07101732e+00 -1.07856165e+00 -1.08770543e+00 -1.10763232e+00
#  -1.12005518e+00 -1.13920990e+00 -1.14799849e+00 -1.16692776e+00
#  -1.17698393e+00 -1.18058059e+00 -1.19300519e+00 -1.24195998e+00
#  -1.24684259e+00 -1.26501879e+00 -1.28804882e+00 -1.30581666e+00
#  -1.31929112e+00 -1.35487374e+00 -1.36532213e+00 -1.37768191e+00
#  -1.39986984e+00 -1.40879696e+00 -1.43479637e+00 -1.45431599e+00
#  -1.48416206e+00 -1.50647330e+00 -1.51896725e+00 -1.53906377e+00
#  -1.56845759e+00 -1.60786860e+00 -1.62431171e+00 -1.64016828e+00
#  -1.65902674e+00 -1.68410359e+00 -1.71849073e+00 -1.77471160e+00
#  -1.81246689e+00 -1.82884810e+00 -1.87125906e+00 -1.88487372e+00
#  -1.96396902e+00 -2.01002341e+00 -2.05467624e+00 -2.08656674e+00
#  -2.14073632e+00 -2.17972631e+00 -2.22049285e+00 -2.25000486e+00
#  -2.30086735e+00 -2.33259998e+00 -2.37522505e+00 -2.44221402e+00
#  -2.49613886e+00 -2.62235231e+00 -2.63938602e+00 -2.73140063e+00
#  -2.77433919e+00 -2.91295918e+00 -2.92312378e+00 -3.09285697e+00
#  -3.12356637e+00 -3.22934273e+00 -3.42755744e+00 -3.74191567e+00
#  -3.79682160e+00 -3.91470651e+00 -4.06542823e+00 -4.18233081e+00
#  -4.40942417e+00 -4.76878810e+00 -5.04722459e+00 -5.23969220e+00
#  -5.52880765e+00 -5.66204182e+00 -6.78763539e+00 -7.07726299e+00
#  -8.18078416e+00 -9.52524803e+00 -1.08180272e+01 -1.08848373e+01
#  -2.52203979e+01 -3.38452120e+01]

# %%
fig = plt.figure()
fig.set_size_inches(10, 10)
ax = fig.add_subplot(111)
ax.set_title('2D Components from Isomap of Facial Images')
ax.set_xlabel('Component: 1')
ax.set_ylabel('Component: 2')

# Show 40 of the images ont the plot
x_size = (max(Z_t['x']) - min(Z_t['x'])) * 0.08
y_size = (max(Z_t['y']) - min(Z_t['y'])) * 0.08
for i in range(40):
    img_num = np.random.randint(0, 600)
    x0 = Z_t.loc[img_num, 'x'] - (x_size / 2.)
    y0 = Z_t.loc[img_num, 'y'] - (y_size / 2.)
    x1 = Z_t.loc[img_num, 'x'] + (x_size / 2.)
    y1 = Z_t.loc[img_num, 'y'] + (y_size / 2.)
    img = np.reshape(np.asarray(data.iloc[:,img_num]), (64,64)).T
    ax.imshow(img, aspect='auto', cmap=plt.cm.gray, 
              interpolation='nearest', zorder=100000, extent=(x0, x1, y0, y1))

# Show 2D components plot
ax.scatter(Z_t['x'], Z_t['y'], marker='.',alpha=0.7)



plt.show()

# %%
Z_t
# Out:
#             x         y  image_no
# 0   -0.553615  0.150385         0
# 1    0.514445 -0.215475         1
# 2   -0.574467  0.020134         2
# 3    0.552808 -0.398368         3
# 4   -0.169181  0.618505         4
# 5    0.520900 -0.465865         5
# 6    0.613496 -0.510007         6
# 7    0.257410 -0.758015         7
# 8    0.812778  0.206534         8
# 9    0.018616  0.546089         9
# 10   0.395561 -0.695141        10
# 11  -0.637965  0.136183        11
# 12   0.155755 -0.604372        12
# 13  -0.413428  0.387478        13
# 14  -0.626063 -0.024950        14
# 15   0.035040  0.744241        15
# 16   0.021908 -0.165860        16
# 17  -0.941259 -0.212387        17
# 18  -0.045770 -0.686317        18
# 19  -0.611688 -0.052779        19
# 20   0.475474 -0.475624        20
# 21  -0.509652  0.198123        21
# 22   0.495446 -0.039800        22
# 23  -0.641765 -0.255796        23
# 24  -0.943009 -0.121931        24
# 25  -0.381079  0.024017        25
# 26   0.492757  0.705267        26
# 27   0.381282  0.081269        27
# 28   0.781749  0.241421        28
# 29   0.860397  0.256916        29
# ..        ...       ...       ...
# 668  0.251003  0.333979       668
# 669  0.808185  0.402555       669
# 670  0.449012  0.689986       670
# 671  0.829049  0.193191       671
# 672  0.797906  0.247067       672
# 673 -0.797335 -0.367884       673
# 674  0.446973 -0.475405       674
# 675  0.200143 -0.171082       675
# 676  0.344061 -0.735985       676
# 677 -0.571395 -0.136732       677
# 678 -0.505704  0.089994       678
# 679 -0.881889 -0.106024       679
# 680 -0.322705  0.212740       680
# 681  0.133573  0.237407       681
# 682 -0.193527 -0.274580       682
# 683 -0.329912 -0.370970       683
# 684 -0.661860 -0.167493       684
# 685  0.438812 -0.518033       685
# 686 -0.123702  0.265517       686
# 687 -0.327116 -0.264760       687
# 688 -0.047478  0.751724       688
# 689  0.159663 -0.900750       689
# 690 -0.313618  0.195168       690
# 691  0.287868 -0.265772       691
# 692  0.642903 -0.533997       692
# 693 -0.819007 -0.240394       693
# 694 -0.760302  0.022949       694
# 695  0.723578  0.457314       695
# 696  0.441105 -0.394791       696
# 697 -0.013394  0.458089       697
#
# [698 rows x 3 columns]

# %%
print (D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad092b0bb7b5> in <module>
# ----> 1 print (D)
#
# NameError: name 'D' is not defined

# %%
data = pd.read_csv("isomap.csv",header=None) # read in the file

# get the pair wise distance matrix of 100 closest points
W = kneighbors_graph(data.T,n_neighbors=100,mode="distance").toarray() 

# adjacency matrix
A = kneighbors_graph(data.T,n_neighbors=100,include_self=False).toarray() 

plt.figure(figsize=(15,10))
sns.heatmap(A)# visulize the adjancency matrix as a heatmap
plt.show()

W[W==0]=8200 # assign the non-existing edge a relative large number
#D = Matrix_D(W) # calculating pairwise shortest distance matrix


import timeit
tic=timeit.default_timer()
D = Matrix_D(W)
toc=timeit.default_timer()
print (toc - tic) #elapsed time in seconds
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-0baafbd88670> in <module>
#      17 import timeit
#      18 tic=timeit.default_timer()
# ---> 19 D = Matrix_D(W)
#      20 toc=timeit.default_timer()
#      21 print (toc - tic) #elapsed time in seconds
#
# <ipython-input-2-50b318c49c9a> in Matrix_D(W)
#      21             Graph.add_weighted_edges_from([(i,j,min(W[i,j], W[j,i]))])
#      22
# ---> 23     res = dict(nx.all_pairs_dijkstra_path_length(Graph))
#      24     D = np.zeros([n,n])
#      25     for i in range(n):
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/weighted.py in all_pairs_dijkstra_path_length(G, cutoff, weight)
#    1047     length = single_source_dijkstra_path_length
#    1048     for n in G:
# -> 1049         yield (n, length(G, n, cutoff=cutoff, weight=weight))
#    1050
#    1051
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/weighted.py in single_source_dijkstra_path_length(G, source, cutoff, weight)
#     371     """
#     372     return multi_source_dijkstra_path_length(G, {source}, cutoff=cutoff,
# --> 373                                              weight=weight)
#     374
#     375
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/weighted.py in multi_source_dijkstra_path_length(G, sources, cutoff, weight)
#     621         raise ValueError('sources must not be empty')
#     622     weight = _weight_function(G, weight)
# --> 623     return _dijkstra_multisource(G, sources, weight, cutoff=cutoff)
#     624
#     625
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/weighted.py in _dijkstra_multisource(G, sources, weight, pred, paths, cutoff, target)
#     830                 continue
#     831             vu_dist = dist[v] + cost
# --> 832             if cutoff is not None:
#     833                 if vu_dist > cutoff:
#     834                     continue
#
# KeyboardInterrupt:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-56:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-44:
# Traceback (most recent call last):
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-43:
# Traceback (most recent call last):
# Process ForkPoolWorker-55:
# Traceback (most recent call last):
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-40:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-46:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-42:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
from multiprocessing import Pool
tic=timeit.default_timer()



num_processors = 3
#Create a pool of processors
p=Pool(processes = num_processors)
#get them to work in parallel
output = p.imap(Matrix_D,W)
print (output)

toc=timeit.default_timer()
print (toc - tic) #elapsed time in seconds
# Out:
# <multiprocessing.pool.IMapIterator object at 0x7f15af362390>
# 0.05150687100831419
# Process ForkPoolWorker-118:
# Process ForkPoolWorker-119:
# Process ForkPoolWorker-117:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
#import Pool
from multiprocessing import Pool

tic=timeit.default_timer()

#Define a worker — a function which will be executed in parallel
def worker(x):
    return x*x^122
#Assuming you want to use 3 processors
num_processors = 3
#Create a pool of processors
p=Pool(processes = num_processors)
#get them to work in parallel
output = p.map(worker,[i for i in range(0,3)])
print(output)



toc=timeit.default_timer()
print (toc - tic) #elapsed time in seconds
# Out:
# [122, 123, 126]
# 0.04121534700971097
# Process ForkPoolWorker-82:
# Process ForkPoolWorker-83:
# Process ForkPoolWorker-84:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/zhang/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt

# %%
import psutil
# logical=True counts threads, but we are interested in cores
psutil.cpu_count(logical=False)
# Out:
# 2

# %%
from multiprocess import Pool
# start your parallel workers at the beginning of your script
pool = Pool(2)
tic=timeit.default_timer()

# execute a computation(s) in parallel
result = pool.map(Matrix_D, W)


# turn off your parallel workers at the end of your script
pool.close()

toc=timeit.default_timer()
print (toc - tic) #elapsed time in seconds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-db67301aa608> in <module>
# ----> 1 from multiprocess import Pool
#       2 # start your parallel workers at the beginning of your script
#       3 pool = Pool(2)
#       4 tic=timeit.default_timer()
#       5
#
# ModuleNotFoundError: No module named 'multiprocess'
